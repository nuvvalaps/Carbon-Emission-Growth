# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database

# %%
pd.set_option('display.max_rows',300)

# %% [markdown]
# # Population Data

# %%
population_csv = "../Resources/Cleaned_CSV/Population_Data.csv"
population = pd.read_csv(population_csv)
population = population.fillna(value='N/A')
population.head()
# Out:
#        Country        Lat       Long Country Code      1990      1991  \
# 0        Aruba  12.521110 -69.968338           AW     62152     64623
# 1  Afghanistan  33.939110  67.709953           AF  12412311  13299016
# 2       Angola -11.202692  17.873887           AO  11848385  12248901
# 3      Albania  41.153332  20.168331           AL   3286542   3266790
# 4      Andorra  42.546245   1.601554           AD     54508     56666
#
#        1992      1993      1994      1995  ...      2010      2011      2012  \
# 0     68240     72495     76705     80324  ...    101665    102050    102565
# 1  14485543  15816601  17075728  18110662  ...  29185511  30117411  31161378
# 2  12657361  13075044  13503753  13945205  ...  23356247  24220660  25107925
# 3   3247039   3227287   3207536   3187784  ...   2913021   2905195   2900401
# 4     58882     60974     62676     63860  ...     84454     83748     82427
#
#        2013      2014      2015      2016      2017      2018      2019
# ...

# %% [markdown]
# # GDP Data

# %%
gdp_csv = "../Resources/Cleaned_CSV/GDP_Data.csv"
gdp = pd.read_csv(gdp_csv)
gdp = gdp.fillna(value='N/A')
gdp.head()
# Out:
#        Country        Lat       Long Country Code          1990          1991  \
# 0        Aruba  12.521110 -69.968338           AW  12306.717679  13495.794301
# 1  Afghanistan  33.939110  67.709953           AF      0.000000      0.000000
# 2       Angola -11.202692  17.873887           AO    947.704262    865.692730
# 3      Albania  41.153332  20.168331           AL    617.230436    336.586995
# 4      Andorra  42.546245   1.601554           AD  18878.852313  19534.263630
#
#            1992          1993          1994          1995  ...          2010  \
# 0  14045.474566  14938.681573  16239.987852  16439.356361  ...  23513.527697
# 1      0.000000      0.000000      0.000000      0.000000  ...    543.306526
# 2    656.362015    441.200842    328.673149    397.179479  ...   3587.883645
# 3    200.852220    367.279225    586.416340    750.604449  ...   4094.348386
# 4  20549.805575  16515.658395  16235.068038  18458.173993  ...  40850.248143
#
# ...

# %% [markdown]
# # Total Emission Data

# %%
total_emission_csv = "../Resources/Cleaned_CSV/Total_Emission_Data.csv"
total_emission = pd.read_csv(total_emission_csv)
total_emission = total_emission.fillna(value='N/A')
total_emission.head()
# Out:
#        Country        Lat       Long Country Code  1990  1991  1992  1993  \
# 0        Aruba  12.521110 -69.968338           AW     0     0     0     0
# 1  Afghanistan  33.939110  67.709953           AF  2380  2230  1390  1340
# 2       Angola -11.202692  17.873887           AO  6560  6670  6880  9270
# 3      Albania  41.153332  20.168331           AL  5980  4060  2220  2060
# 4      Andorra  42.546245   1.601554           AD   410   410   410   410
#
#     1994   1995  ...          2010          2011          2012          2013  \
# 0      0      0  ...      0.000000      0.000000      0.000000      0.000000
# 1   1290   1240  ...   7110.000134   8930.000305   8079.999924   5989.999771
# 2  11300  12720  ...  22799.999237  23870.000839  23870.000839  26959.999084
# 3   2070   1930  ...   4449.999809   4849.999905   4360.000134   4440.000057
# 4    410    430  ...    519.999981    490.000010    490.000010    479.999989
#
# ...

# %% [markdown]
# # Gas Emission Data

# %%
gas_emission_csv = "../Resources/Cleaned_CSV/Gas_Emission_Data.csv"
gas_emission = pd.read_csv(gas_emission_csv)
gas_emission = gas_emission.fillna(value='N/A')
gas_emission.head()
# Out:
#        Country        Lat       Long Country Code       1990       1991  \
# 0        Aruba  12.521110 -69.968338           AW   0.000000   0.000000
# 1  Afghanistan  33.939110  67.709953           AF  13.627365  14.186204
# 2       Angola -11.202692  17.873887           AO  15.988815  16.622236
# 3      Albania  41.153332  20.168331           AL   7.697669   6.691606
# 4      Andorra  42.546245   1.601554           AD   0.000000   0.000000
#
#         1992       1993       1994       1995  ...      2010      2011  \
# 0   0.000000   0.000000   0.000000   0.000000  ...  0.000000  0.000000
# 1  25.386923  25.884706  25.951077  25.815680  ...  3.129850  2.512463
# 2  16.751915  15.199449  14.525486   9.728776  ...  4.807073  4.767349
# 3   8.840089   7.617440   4.626589   2.632718  ...  0.560459  0.582063
# 4   0.000000   0.000000   0.000000   0.000000  ...  0.000000  0.000000
#
#        2012      2013      2014      2015      2016  2017  2018  2019
# ...

# %% [markdown]
# # Liquid Emission Data

# %%
liquid_emission_csv = "../Resources/Cleaned_CSV/Liquid_Emission_Data.csv"
liquid_emission = pd.read_csv(liquid_emission_csv)
liquid_emission = liquid_emission.fillna(value='N/A')
liquid_emission.head()
# Out:
#        Country        Lat       Long Country Code       1990       1991  \
# 0        Aruba  12.521110 -69.968338           AW   0.000000   0.000000
# 1  Afghanistan  33.939110  67.709953           AF  62.561993  62.767263
# 2       Angola -11.202692  17.873887           AO  39.161011  34.985314
# 3      Albania  41.153332  20.168331           AL  35.942661  54.246618
# 4      Andorra  42.546245   1.601554           AD  99.277317  99.277317
#
#         1992        1993       1994       1995  ...       2010        2011  \
# 0   0.000000    0.000000   0.000000   0.000000  ...   0.000000    0.000000
# 1  64.877692   65.790294  66.006000  66.006000  ...  67.714729   62.063825
# 2  35.979199   43.047391  19.403857  78.136354  ...  46.901097   48.731517
# 3  63.190268   71.568502  75.053551  91.016821  ...  76.302424   74.940675
# 4  99.277317  100.171707  99.277317  98.923721  ...  99.432115  100.281224
#
#         2012       2013        2014       2015       2016  2017  2018  2019
# ...

# %% [markdown]
# # Solid Emission Data

# %%
solid_emission_csv = "../Resources/Cleaned_CSV/Solid_Emission_Data.csv"
solid_emission = pd.read_csv(solid_emission_csv)
solid_emission = solid_emission.fillna(value='N/A')
solid_emission.head()
# Out:
#        Country        Lat       Long Country Code       1990       1991  \
# 0        Aruba  12.521110 -69.968338           AW   0.000000   0.000000
# 1  Afghanistan  33.939110  67.709953           AF   9.415270   9.100584
# 2       Angola -11.202692  17.873887           AO   0.000000   0.000000
# 3      Albania  41.153332  20.168331           AL  41.337091  36.045450
# 4      Andorra  42.546245   1.601554           AD   0.000000   0.000000
#
#         1992       1993      1994      1995  ...       2010       2011  \
# 0   0.000000   0.000000  0.000000  0.000000  ...   0.000000   0.000000
# 1   1.538601   1.348162  1.128308  1.173440  ...  26.519135  35.114666
# 2   0.000000   0.000000  0.000000  0.000000  ...   0.000000   0.000000
# 3  35.687768  29.052560  7.882336  8.274256  ...   9.367664  10.622659
# 4   0.000000   0.000000  0.000000  0.000000  ...   0.000000   0.000000
#
#         2012       2013       2014       2015       2016  2017  2018  2019
# ...

# %% [markdown]
# # Combining Dataframes

# %%
joined = pd.concat([population,gdp,total_emission,gas_emission,liquid_emission,solid_emission])
joined.head()
# Out:
#        Country        Lat       Long Country Code        1990        1991  \
# 0        Aruba  12.521110 -69.968338           AW     62152.0     64623.0
# 1  Afghanistan  33.939110  67.709953           AF  12412311.0  13299016.0
# 2       Angola -11.202692  17.873887           AO  11848385.0  12248901.0
# 3      Albania  41.153332  20.168331           AL   3286542.0   3266790.0
# 4      Andorra  42.546245   1.601554           AD     54508.0     56666.0
#
#          1992        1993        1994        1995  ...        2010  \
# 0     68240.0     72495.0     76705.0     80324.0  ...    101665.0
# 1  14485543.0  15816601.0  17075728.0  18110662.0  ...  29185511.0
# 2  12657361.0  13075044.0  13503753.0  13945205.0  ...  23356247.0
# 3   3247039.0   3227287.0   3207536.0   3187784.0  ...   2913021.0
# 4     58882.0     60974.0     62676.0     63860.0  ...     84454.0
#
#          2011        2012        2013        2014        2015        2016  \
# ...

# %%
joined = joined.fillna(value='N/A')
joined
# Out:
#           Country        Lat        Long Country Code          1990  \
# 0           Aruba  12.521110  -69.968338           AW  6.215200e+04
# 1     Afghanistan  33.939110   67.709953           AF  1.241231e+07
# 2          Angola -11.202692   17.873887           AO  1.184838e+07
# 3         Albania  41.153332   20.168331           AL  3.286542e+06
# 4         Andorra  42.546245    1.601554           AD  5.450800e+04
# ..            ...        ...         ...          ...           ...
# 205         Samoa -13.759029 -172.104629           WS  0.000000e+00
# 206         Yemen  15.552727   48.516388           YE  0.000000e+00
# 207  South Africa -30.559482   22.937506           ZA  1.071286e+02
# 208        Zambia -13.133897   27.849332           ZM  3.037989e+01
# 209      Zimbabwe -19.015438   29.154857           ZW  8.123747e+01
#
#              1991          1992          1993          1994          1995  \
# 0    6.462300e+04  6.824000e+04  7.249500e+04  7.670500e+04  8.032400e+04
# ...

# %%
joined.to_csv("../Resources/Final_CSV/Data.csv", index=False)

# %% [markdown]
# # Database to SQL

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5432
database_name = 'World_Data'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
if not database_exists(engine.url):
    create_database(engine.url)

# %%
engine.table_names()
# Out:
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_3116\4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['World_Data']

# %%
joined.to_sql(name='World_Data', con=engine, if_exists='append', index=False)
# Out:
# 260

# %%
engine.table_names()
# Out:
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_3116\4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['World_Data']

# %%
# data_list = ['000']
# internal_list = ['000']

# %%
# dict_data = {}
# dict_year = {}

# %%
# for year in range(1990,2020):
#     data_list = data_list.append({"date":f'{year}'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
#       1 for year in range(1990,2020):
# ----> 2     data_list = data_list.append({"date":year})
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
# data_list

# %%
# for index,year in population.iterrows():
#     dict_data["population"] = [f'{year}']
    
    
#     dict_data["gdp"] = gdp[f'{year}']
#     dict_data["total_emissions"] = total_emission[f'{year}']
#     dict_data["gas_emissions"] = gas_emission[f'{year}']
#     dict_data["liquid_emissions"] = liquid_emission[f'{year}']
#     dict_data["solid_emissions"] = solid_emission[f'{year}']
#     dict_data["id"] =  population['Country Code']

# %%
# dict_data

# %%
# print(internal_list)

# %%
# for year in range(1990,2020):
#     internal_list = internal_list.append(dict_data)

# %%
# for year in range(1990,2020):
#     data_list = data_list.append({"date":f'{year}',"list":internal_list})
